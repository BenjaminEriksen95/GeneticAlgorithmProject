# %% [markdown]
# # Analysis

# %%
import sys
# !{sys.executable} -m pip install numpy pandas matplotlib seaborn

# %%
# Installs
#!python -m pip install pandas matplotlib numpy
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from plots import plot_problem, mean_score

# %%
onemax = pd.read_csv("../results/LeadingOnes.csv",sep=";")

# %%
onemax
# Out:
#                  algorithm  goal  solved  best_fitness  explored  iterations  \
# 0     Adaptive Mutation GA    10    True            10        56          10
# 1     Adaptive Mutation GA    10    True            10        41           7
# 2     Adaptive Mutation GA    10    True            10        56          10
# 3     Adaptive Mutation GA    10    True            10        26           4
# 4     Adaptive Mutation GA    10    True            10        71          13
# ...                    ...   ...     ...           ...       ...         ...
# 1045           Standard GA   250   False            48      8300          80
# 1046           Standard GA   250   False            28      8300          80
# 1047           Standard GA   250   False            55      8300          80
# 1048           Standard GA   250   False            34      8300          80
# 1049           Standard GA   250   False            18      8300          80
#
# ...

# %%
plot_problem(onemax)
# Time vs problem size with mean and 95% confidence interval
# Explored space vs problem size with mean and 95% confidence interval

# %%
onemax.loc[onemax['solved'] == True].groupby(["algorithm","goal"])[["explored","time"]].agg(['mean','min','max'])
# Out:
#                                explored                     time             \
#                                    mean    min    max       mean        min
# algorithm            goal
# Adaptive Mutation GA 10       63.333333     26    101   0.004296   0.001556
#                      30      545.000000    351    906   0.076249   0.048206
#                      50     1587.666667   1016   2531   0.355081   0.230460
#                      70     2670.666667   1901   3916   0.776111   0.530850
#                      90     4511.333333   2926   6751   1.576818   1.002832
#                      100    5530.333333   3931   6641   2.157789   1.558253
#                      120    8207.000000   5491   9961   3.775648   2.477445
#                      140   11411.666667   9136  15781   6.235886   4.913761
#                      160   13677.000000  10861  16481   8.034776   6.080566
#                      180   17503.727273  14886  19351  13.077112  11.120778
# ...

# %%
#df = onemax.groupby(["algorithm","goal"])[['best_fitness']].agg(['mean'])
#df.columns = ["_".join(x) for x in df.columns.ravel()]
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.

# %%
mean_score(onemax)

# %%
#g = sns.FacetGrid(df.reset_index(), hue='algorithm', height=10)
#g.map(sns.lineplot, "goal", 'best_fitness_mean')

# %%
def f(x):
    return math.log(x)
